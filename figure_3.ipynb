# %% [markdown]
# ## panel bc

# %%
from lib.figure_3 import figure_3_panel_bc

figure_3_panel_bc(reset=True)
# Out:
#   0%|          | 0/31 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from lib.figure_3 import figure_3_panel_bc
# ----> 3 figure_3_panel_bc(reset=True)
#
# File ~/PSRP_RPD/lib/figure_3.py:114, in figure_3_panel_bc(reset)
#     112 if not isfile(binned_file) or reset:
#     113     total_spike_times = [np.divide(np.histogram(relative_trial_spikes, bins=np.arange(WINDOW_LEFT, WINDOW_RIGHT+BIN_SIZE, BIN_SIZE))[0], BIN_SIZE) for relative_trial_spikes in relative_to_pfc]
# --> 114     binned_data = np.ndarray([signal_spike_times, mvt_spike_times, reward_spike_times, total_spike_times], dtype=object)
#     115     # save the binned spike times
#     116     np.save(binned_file, [signal_spike_times, mvt_spike_times, reward_spike_times, total_spike_times])
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
from lib.figure_3 import figure_3_panel_bc_mid

figure_3_panel_bc_mid()

# %%
from lib.figure_3 import figure_3_panel_bc_bottom

figure_3_panel_bc_bottom()
# Out:
# PFC
# signal coeffs
# signal vs mvt t test: t = 2.2444565642137446, p = 0.024869492945643206
# signal vs reward t test: t = 1.1493706552968155, p = 0.2504868490618157
# mvt vs reward t test: t = -1.1248745997957592, p = 0.26072361607285793
# mvt coeffs
# signal vs mvt t test: t = -15.356005795517518, p = 1.9142238108802123e-51
# signal vs reward t test: t = -13.958434443086464, p = 4.6350596987601574e-43
# mvt vs reward t test: t = 0.7026485192660031, p = 0.4823241540968525
# reward coeffs
# signal vs mvt t test: t = 3.814595670914973, p = 0.00013892067367966056
# signal vs reward t test: t = -6.139956431295591, p = 9.241736814686519e-10
# mvt vs reward t test: t = -8.574579870612206, p = 1.502479120219918e-17
# DMS
# signal coeffs
# signal vs mvt t test: t = -1.093096916027304, p = 0.27448916736556883
# signal vs reward t test: t = -2.161987915220879, p = 0.030743133175717113
# mvt vs reward t test: t = -1.0018197916566547, p = 0.31655557439640786
# mvt coeffs
# signal vs mvt t test: t = -9.586282948451883, p = 2.729802390750217e-21
# signal vs reward t test: t = -9.569779967284141, p = 3.182801580574183e-21
# mvt vs reward t test: t = -0.49460442049569225, p = 0.6209353855894066
# reward coeffs
# signal vs mvt t test: t = 3.2095612170536354, p = 0.0013514487651109916
# signal vs reward t test: t = -8.952695053944089, p = 8.033772750885116e-19
# mvt vs reward t test: t = -10.528058057617928, p = 3.031249972328708e-25
