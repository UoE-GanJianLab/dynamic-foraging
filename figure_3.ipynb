# %% [markdown]
# ## panel bc

# %%
from lib.figure_3_4 import get_figure_3_panel_ab

get_figure_3_panel_ab()

# %%
from lib.figure_3_4 import get_figure_3_panel_cd

get_figure_3_panel_cd()

# %%
from lib.figure_3_4 import get_figure_3_panel_ef

get_figure_3_panel_ef()
# Out:
# PFC
# signal coeffs
# signal vs mvt t test: t = 2.2444565642137477, p = 0.02486949294564299
# signal vs reward t test: t = 1.1493706552968272, p = 0.25048684906181073
# mvt vs reward t test: t = -1.124874599795751, p = 0.2607236160728613
# mvt coeffs
# signal vs mvt t test: t = -15.35600579551751, p = 1.9142238108803485e-51
# signal vs reward t test: t = -13.958434443086464, p = 4.6350596987601574e-43
# mvt vs reward t test: t = 0.702648519265996, p = 0.4823241540968568
# reward coeffs
# signal vs mvt t test: t = 3.8145956709149718, p = 0.00013892067367966121
# signal vs reward t test: t = -6.139956431295594, p = 9.24173681468635e-10
# mvt vs reward t test: t = -8.574579870612206, p = 1.502479120219918e-17
# DMS
# signal coeffs
# signal vs mvt t test: t = -1.0930969160273138, p = 0.27448916736556467
# signal vs reward t test: t = -2.161987915220856, p = 0.03074313317571895
# mvt vs reward t test: t = -1.0018197916566247, p = 0.31655557439642235
# mvt coeffs
# ...

# %%
from lib.figure_3_4 import get_figure_3_panel_d

get_figure_3_panel_d()
# Out:
# PFC signal t test: t = 1.8052033066860114, p = 0.07113589892813288
# PFC movement t test: t = -1.2932709688947672, p = 0.196009784754571
# PFC reward t test: t = 6.147045057846161, p = 8.859018238891448e-10
# DMS signal t test: t = 0.6694651724573993, p = 0.503280131965345
# DMS movement t test: t = -0.8082013223880229, p = 0.41907587363185894
# DMS reward t test: t = 1.2463704651020782, p = 0.21278206212263295
