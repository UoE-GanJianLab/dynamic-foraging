# %% [markdown]
# ## panel bc

# %%
from lib.figure_3 import figure_3_panel_bc

figure_3_panel_bc(reset=True)
# Out:
# 100%|██████████| 31/31 [00:07<00:00,  4.32it/s]

# %%
from lib.figure_3 import figure_3_panel_bc_mid

figure_3_panel_bc_mid()

# %%
from lib.figure_3 import figure_3_panel_bc_bottom

figure_3_panel_bc_bottom()
# Out:
# (array([ 0.15122806,  0.07767301, -0.02762562, -0.03425088]), array([2.93702347]), 4, array([40.62936649,  4.35503385,  2.16206761,  0.46280187]))
# (array([-0.63058862,  0.29531257, -0.17078004,  0.25322738]), array([3.80112881]), 4, array([40.62936649,  4.35503385,  2.16206761,  0.46280187]))
# (array([ 0.01638152,  0.09154501,  0.06821744, -0.57311273]), array([2.52038003]), 4, array([40.62936649,  4.35503385,  2.16206761,  0.46280187]))
# (array([ 0.59930057, -0.14628618,  0.06085303, -0.00447271]), array([6.38115431]), 4, array([40.62936649,  4.35503385,  2.16206761,  0.46280187]))
# (array([ 0.37958662,  0.02871495,  0.1340021 , -0.24809796]), array([1.09471002]), 4, array([40.62936649,  4.35503385,  2.16206761,  0.46280187]))
# (array([-0.57812599,  0.22565129,  0.0522664 ,  0.14637103]), array([2.49929565]), 4, array([40.62936649,  4.35503385,  2.16206761,  0.46280187]))
# ...
