# %% [markdown]
# ## panel bc

# %%
from lib.figure_3 import figure_3_panel_bc

figure_3_panel_bc(reset=False)

# %%
from lib.figure_3 import figure_3_panel_bc_mid

figure_3_panel_bc_mid()

# %%
from lib.figure_3 import figure_3_panel_bc_bottom

figure_3_panel_bc_bottom()
# Out:
# PFC
# signal coeffs
# signal vs mvt t test: t = 2.2444565642137446, p = 0.024869492945643206
# signal vs reward t test: t = 1.1493706552968155, p = 0.2504868490618157
# mvt vs reward t test: t = -1.1248745997957592, p = 0.26072361607285793
# mvt coeffs
# signal vs mvt t test: t = -15.356005795517518, p = 1.9142238108802123e-51
# signal vs reward t test: t = -13.958434443086464, p = 4.6350596987601574e-43
# mvt vs reward t test: t = 0.7026485192660031, p = 0.4823241540968525
# reward coeffs
# signal vs mvt t test: t = 3.814595670914973, p = 0.00013892067367966056
# signal vs reward t test: t = -6.139956431295591, p = 9.241736814686519e-10
# mvt vs reward t test: t = -8.574579870612206, p = 1.502479120219918e-17
# DMS
# signal coeffs
# signal vs mvt t test: t = -1.0930969160273105, p = 0.27448916736556606
# signal vs reward t test: t = -2.1619879152208727, p = 0.03074313317571762
# mvt vs reward t test: t = -1.0018197916566431, p = 0.31655557439641346
# mvt coeffs
# signal vs mvt t test: t = -9.586282948451885, p = 2.729802390750197e-21
# signal vs reward t test: t = -9.569779967284141, p = 3.182801580574183e-21
# mvt vs reward t test: t = -0.4946044204956908, p = 0.6209353855894075
# reward coeffs
# signal vs mvt t test: t = 3.209561217053631, p = 0.0013514487651110124
# signal vs reward t test: t = -8.95269505394409, p = 8.033772750885116e-19
# mvt vs reward t test: t = -10.528058057617928, p = 3.031249972328708e-25

# %%
from lib.figure_3 import figure_3_panel_d

figure_3_panel_d()
# Out:
# PFC signal t test: t = 1.805203306686017, p = 0.071135898928132
# PFC movement t test: t = -1.2932709688947686, p = 0.1960097847545706
# PFC reward t test: t = 6.14704505784616, p = 8.859018238891513e-10
# DMS signal t test: t = 0.6694651724574019, p = 0.5032801319653433
# DMS movement t test: t = -0.808201322388026, p = 0.4190758736318573
# DMS reward t test: t = 1.2463704651020773, p = 0.2127820621226333
