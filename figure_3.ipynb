# %% [markdown]
# ## panel bc

# %%
from lib.figure_3_4 import get_figure_3_panel_ab

get_figure_3_panel_ab(reset=True, prpd=True)
# Out:
#   3%|▎         | 1/31 [00:00<00:04,  6.29it/s]
# mvt_left_idx 84
# mvt_right_idx 26
# Error: dms_0 not found in prpd_correlation
# mvt_left_idx 33
# mvt_right_idx 99
#  10%|▉         | 3/31 [00:00<00:05,  5.60it/s]
# Error: dms_41 not found in prpd_correlation
# Error: dms_63 not found in prpd_correlation
# mvt_left_idx 116
# mvt_right_idx 133
# mvt_left_idx 64
# mvt_right_idx 79
#  13%|█▎        | 4/31 [00:00<00:05,  5.23it/s]
# mvt_left_idx 64
# mvt_right_idx 47
# Error: pfc_37 not found in prpd_correlation
# Error: pfc_34 not found in prpd_correlation
#  16%|█▌        | 5/31 [00:01<00:05,  4.48it/s]
# mvt_left_idx 59
# mvt_right_idx 31
# Error: pfc_0 not found in prpd_correlation
# mvt_left_idx 55
# mvt_right_idx 109
#  23%|██▎       | 7/31 [00:01<00:05,  4.68it/s]
# mvt_left_idx 89
# mvt_right_idx 43
# mvt_left_idx 128
# mvt_right_idx 23
#  32%|███▏      | 10/31 [00:01<00:03,  6.14it/s]
# mvt_left_idx 29
# mvt_right_idx 92
# mvt_left_idx 137
# mvt_right_idx 93
# ...

# %%
from lib.figure_3_4 import get_figure_3_panel_cd

get_figure_3_panel_cd()

# %%
from lib.figure_3_4 import get_figure_3_panel_ef

get_figure_3_panel_ef()
# Out:
# PFC
# signal coeffs
# signal vs mvt t test: t = -1.786985071312701, p = 0.0743271341890005
# signal vs reward t test: t = -1.8424650604648518, p = 0.06578554482499141
# mvt vs reward t test: t = -0.07515499707037443, p = 0.9401104167818616
# mvt coeffs
# signal vs mvt t test: t = -9.045125644690708, p = 1.162302937065909e-18
# signal vs reward t test: t = -8.960233375036426, p = 2.3424894448351913e-18
# mvt vs reward t test: t = -0.15559160979757947, p = 0.8763946854794452
# reward coeffs
# signal vs mvt t test: t = 3.8331600757011657, p = 0.0001366701942979971
# signal vs reward t test: t = -2.918035105777482, p = 0.0036234467319447993
# mvt vs reward t test: t = -5.648930759509488, p = 2.2532666135306244e-08
# DMS
# signal coeffs
# signal vs mvt t test: t = -1.0256506963211653, p = 0.305550225139759
# signal vs reward t test: t = -1.3055380953743443, p = 0.19230768596548226
# mvt vs reward t test: t = -0.3205233720305694, p = 0.7487039388397254
# mvt coeffs
# ...

# %%
from lib.figure_3_4 import get_figure_3_panel_ef_direction_modulation

get_figure_3_panel_ef_direction_modulation()
# Out:
# /home/peiheng/PSRP_RPD/lib/figure_3_4.py:690: RuntimeWarning: invalid value encountered in divide
#   reward_spike_times_right = reward_spike_times_right / np.max(reward_spike_times_right)
# /home/peiheng/PSRP_RPD/lib/figure_3_4.py:689: RuntimeWarning: invalid value encountered in divide
#   reward_spike_times_left = reward_spike_times_left / np.max(reward_spike_times_left)
# /home/peiheng/PSRP_RPD/lib/figure_3_4.py:705: RuntimeWarning: invalid value encountered in divide
#   mvt_spike_times_left = mvt_spike_times_left / np.max(mvt_spike_times_left)
# /home/peiheng/PSRP_RPD/lib/figure_3_4.py:711: RuntimeWarning: invalid value encountered in divide
#   reward_spike_times_right = reward_spike_times_right / np.max(reward_spike_times_right)
# PFC
# mvt coeffs
# signal left vs right t test: t = 0.017024833325796993, p = 0.986421103140974
# mvt left vs right t test: t = 0.3122466255799609, p = 0.7549354965837308
# ...

# %%
from lib.figure_3_4 import get_figure_4_panel_ab

get_figure_4_panel_ab()
# Out:
# PFC signal t test: t = 0.71286565965253, p = 0.4761418187691898
# PFC movement t test: t = -0.1824403811558258, p = 0.8552844826149337
# PFC reward t test: t = 3.131903558494558, p = 0.0018015355467375582
# DMS signal t test: t = -0.7675757261067812, p = 0.44310233051419656
# DMS movement t test: t = -1.8986956589605783, p = 0.05818109100872082
# DMS reward t test: t = 1.9856932605321194, p = 0.04761422680699849

# %%
from lib.figure_3_4 import get_figure_4_panel_ab_lr

get_figure_4_panel_ab_lr()
# Out:
# [[ 0.02833904  0.02585951 -0.01029226]
#  [-0.01429429  0.00650708  0.01256671]
#  [ 0.04362433  0.07245393 -0.01246089]
#  ...
#  [ 0.087113    0.00989984  0.02564664]
#  [ 0.05940247  0.03181572  0.0237826 ]
#  [ 0.00717045  0.0199977   0.05295622]]
# PFC signal t test: t = 0.15742391331038133, p = 0.8749509940472597
# PFC movement t test: t = -0.022854809990642475, p = 0.9817718586922894
# PFC reward t test: t = -0.3532004152846035, p = 0.7240324213554052
# DMS signal t test: t = 0.7441719757702571, p = 0.45711787826457606
# DMS movement t test: t = 0.3990098061166067, p = 0.6900543161811631
# DMS reward t test: t = -0.36393236700504, p = 0.7160605297586683
