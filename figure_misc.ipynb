# %%
from lib.figure_misc import prpd_firing_rate_vs_advantageous_proportion

prpd_firing_rate_vs_advantageous_proportion()
# Out:
# 100%|██████████| 31/31 [00:15<00:00,  2.00it/s]
# (81, 20)
# (3001, 20)

# %%
from lib.figure_misc import prpd_firing_rate_vs_advantageous_proportion

prpd_firing_rate_vs_advantageous_proportion(type='PFC')
# Out:
# 100%|██████████| 31/31 [00:09<00:00,  3.34it/s]
# (81, 20)
# (1762, 20)

# %%
from lib.figure_misc import prpd_firing_rate_vs_advantageous_proportion

prpd_firing_rate_vs_advantageous_proportion(type='DMS')
# Out:
# 100%|██████████| 31/31 [00:06<00:00,  5.05it/s]
# (81, 20)
# (1239, 20)
