# %%
from lib.beri_cohen_extra import pastP_futureP_vs_relative_value

pastP_futureP_vs_relative_value()

# %%
from lib.beri_cohen_extra import pastP_futureP_vs_relative_value

pastP_futureP_vs_relative_value()
