# %%
from lib.figure_8 import figure_8_panel_ei

figure_8_panel_ei(mono=False)
# Out:
#   0%|          | 0/29 [1:59:14<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/anaconda3/envs/work/lib/python3.11/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/peiheng/PSRP_RPD/figure_8.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/peiheng/PSRP_RPD/figure_8.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from lib.figure_8 import figure_8_panel_ei
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/peiheng/PSRP_RPD/figure_8.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> figure_8_panel_ei(mono=False)
#
# ...

# %%
from lib.figure_8 import figure_8_panel_dh

figure_8_panel_dh(mono=True)

figure_8_panel_dh(mono=False)
# Out:
# 590it [00:06, 96.53it/s]
# t: -3.439937909343383, p: 0.0005646506319530828
# positive: 0.2416005557373287, positive sem 0.04612683966897185, negative: 0.47296076903541673, negative: 0.04726813576845457
# 100%|██████████| 29/29 [04:26<00:00,  9.18s/it]
# t: -8.020560608781873, p: 3.576158011492007e-11
# positive: 0.21256045981750937, positive sem 0.01896898691650735, negative: 0.4823505884609281, negative: 0.027067145489790972

# %%
from lib.figure_8 import figure_8_panel_gk

figure_8_panel_gk(mono=False)

figure_8_panel_gk(mono=True)
# Out:
# 100%|██████████| 29/29 [00:04<00:00,  5.93it/s]
# t: -11.346109395585442, p: 7.759470178631417e-30
# 590it [00:00, 1093.42it/s]
# t: -4.816077602739089, p: 1.467582757323592e-06

# %%
from lib.figure_8 import figure_8_panel_fj

figure_8_panel_fj(mono=True)

figure_8_panel_fj(mono=False)
# Out:
# 590it [00:00, 821.89it/s]
# t: -8.25042155367643, p: 1.589269367196152e-16
# 100%|██████████| 29/29 [00:14<00:00,  1.97it/s]
# t: -126.04463707034033, p: 0.0

# %%
from lib.figure_6 import figure_6_poster_panel_f

figure_6_poster_panel_f(reset=False, mono=False)
# Out:
# 100%|██████████| 29/29 [03:41<00:00,  7.62s/it]
# [[ -4.2958133   -5.08307415  -6.46297029 ... -97.75535912 -91.96765701
#   -87.08346247]
#  [ 93.17736776  92.79438191  92.57149287 ... -44.7192802  -46.35182685
#   -49.66277025]
#  [-22.53269227 -26.46816042 -28.94036932 ...  23.26526997  22.56202888
#    22.89380414]
#  ...
#  [166.05888978 167.44247562 168.32950195 ...  36.39353287  34.69451944
#    33.60196903]
#  [136.45204539 138.33365004 139.80834343 ... -77.81764953 -78.60298963
#   -79.37743438]
#  [192.88970537 196.683525   198.88763028 ...  31.27864893  27.47616246
#    24.90381811]]

# %%
from lib.figure_8 import figure_6_poster_panel_f

figure_6_poster_panel_f(mono=True)
# Out:
# 590it [00:04, 124.67it/s]
# ...
